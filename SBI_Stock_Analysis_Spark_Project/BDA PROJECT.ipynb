# %%
# File location and type
file_location = "/FileStore/tables/SBI_Stock-1.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>Open</th><th>High</th><th>Low</th><th>Last</th><th>Close</th><th>Volume</th><th>Turnover</th></tr></thead><tbody><tr><td>2000-01-03T00:00:00.000+0000</td><td>236.0</td><td>243.65</td><td>234.25</td><td>243.65</td><td>243.65</td><td>2373228</td><td>5.71534E13</td></tr><tr><td>2000-01-04T00:00:00.000+0000</td><td>243.65</td><td>262.0</td><td>238.85</td><td>258.0</td><td>259.1</td><td>4495741</td><td>1.13051E14</td></tr><tr><td>2000-01-05T00:00:00.000+0000</td><td>249.0</td><td>264.7</td><td>245.0</td><td>249.05</td><td>248.45</td><td>3434058</td><td>8.66601E13</td></tr><tr><td>2000-01-06T00:00:00.000+0000</td><td>252.0</td><td>268.0</td><td>252.0</td><td>260.5</td><td>261.0</td><td>6658801</td><td>1.74582E14</td></tr><tr><td>2000-01-07T00:00:00.000+0000</td><td>261.5</td><td>279.9</td><td>255.0</td><td>279.0</td><td>273.3</td><td>7873985</td><td>2.11829E14</td></tr><tr><td>2000-01-10T00:00:00.000+0000</td><td>280.0</td><td>289.85</td><td>265.2</td><td>266.0</td><td>269.5</td><td>5519316</td><td>1.54425E14</td></tr><tr><td>2000-01-11T00:00:00.000+0000</td><td>266.8</td><td>267.0</td><td>247.95</td><td>247.95</td><td>247.95</td><td>2427606</td><td>6.18219E13</td></tr><tr><td>2000-01-12T00:00:00.000+0000</td><td>244.0</td><td>251.5</td><td>236.6</td><td>244.0</td><td>244.75</td><td>2805072</td><td>6.83616E13</td></tr><tr><td>2000-01-13T00:00:00.000+0000</td><td>246.0</td><td>255.6</td><td>243.1</td><td>243.15</td><td>244.5</td><td>3226776</td><td>8.06835E13</td></tr><tr><td>2000-01-14T00:00:00.000+0000</td><td>245.0</td><td>245.0</td><td>238.1</td><td>239.05</td><td>239.2</td><td>1506543</td><td>3.62406E13</td></tr><tr><td>2000-01-17T00:00:00.000+0000</td><td>244.4</td><td>251.0</td><td>232.3</td><td>236.1</td><td>235.9</td><td>4385887</td><td>1.05359E14</td></tr><tr><td>2000-01-18T00:00:00.000+0000</td><td>236.9</td><td>241.0</td><td>233.75</td><td>236.5</td><td>236.45</td><td>2706614</td><td>6.43074E13</td></tr><tr><td>2000-01-19T00:00:00.000+0000</td><td>240.9</td><td>247.5</td><td>240.0</td><td>243.0</td><td>243.95</td><td>2511949</td><td>6.14508E13</td></tr><tr><td>2000-01-20T00:00:00.000+0000</td><td>243.0</td><td>244.8</td><td>236.25</td><td>237.9</td><td>237.7</td><td>1158464</td><td>2.78738E13</td></tr><tr><td>2000-01-21T00:00:00.000+0000</td><td>238.75</td><td>239.75</td><td>235.5</td><td>237.0</td><td>237.45</td><td>1178627</td><td>2.79996E13</td></tr><tr><td>2000-01-24T00:00:00.000+0000</td><td>236.65</td><td>240.35</td><td>227.1</td><td>228.1</td><td>228.3</td><td>1855636</td><td>4.35836E13</td></tr><tr><td>2000-01-25T00:00:00.000+0000</td><td>226.0</td><td>227.9</td><td>222.6</td><td>225.5</td><td>224.85</td><td>2226513</td><td>5.01233E13</td></tr><tr><td>2000-01-27T00:00:00.000+0000</td><td>229.0</td><td>235.5</td><td>228.0</td><td>230.8</td><td>230.15</td><td>2000745</td><td>4.6439E13</td></tr><tr><td>2000-01-28T00:00:00.000+0000</td><td>232.7</td><td>248.6</td><td>232.7</td><td>248.6</td><td>248.5</td><td>4978231</td><td>1.22105E14</td></tr><tr><td>2000-01-31T00:00:00.000+0000</td><td>246.0</td><td>256.75</td><td>242.5</td><td>242.95</td><td>244.7</td><td>4829071</td><td>1.213E14</td></tr><tr><td>2000-02-01T00:00:00.000+0000</td><td>245.0</td><td>250.7</td><td>242.75</td><td>250.0</td><td>246.5</td><td>2196468</td><td>5.39759E13</td></tr><tr><td>2000-02-02T00:00:00.000+0000</td><td>257.0</td><td>258.7</td><td>246.0</td><td>246.9</td><td>247.5</td><td>2328315</td><td>5.8745E13</td></tr><tr><td>2000-02-03T00:00:00.000+0000</td><td>250.0</td><td>264.9</td><td>248.6</td><td>257.85</td><td>258.8</td><td>7332794</td><td>1.89568E14</td></tr><tr><td>2000-02-04T00:00:00.000+0000</td><td>260.0</td><td>264.75</td><td>254.5</td><td>256.5</td><td>255.9</td><td>3206295</td><td>8.32489E13</td></tr><tr><td>2000-02-07T00:00:00.000+0000</td><td>258.7</td><td>258.7</td><td>243.6</td><td>245.5</td><td>247 ...

# %%
# Create a view or table

temp_table_name = "SBI_Stock-1_csv"

df.createOrReplaceTempView(temp_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `SBI_Stock-1_csv`

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "SBI_Stock-1_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)

# %% [markdown]
# Showing the Columns

# %%
df.columns
# Out:
# Out[10]: ['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Volume', 'Turnover']

# %% [markdown]
# Print the Schema.

# %%
df.printSchema()
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Last: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Turnover: double (nullable = true)

# %% [markdown]
# Print first 20 Columns

# %%
for line in df.head(20):
    print(line, '\n')
# Out:
# Row(Date=datetime.datetime(2000, 1, 3, 0, 0), Open=236.0, High=243.65, Low=234.25, Last=243.65, Close=243.65, Volume=2373228, Turnover=57153400000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 4, 0, 0), Open=243.65, High=262.0, Low=238.85, Last=258.0, Close=259.1, Volume=4495741, Turnover=113051000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 5, 0, 0), Open=249.0, High=264.7, Low=245.0, Last=249.05, Close=248.45, Volume=3434058, Turnover=86660100000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 6, 0, 0), Open=252.0, High=268.0, Low=252.0, Last=260.5, Close=261.0, Volume=6658801, Turnover=174582000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 7, 0, 0), Open=261.5, High=279.9, Low=255.0, Last=279.0, Close=273.3, Volume=7873985, Turnover=211829000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 10, 0, 0), Open=280.0, High=289.85, Low=265.2, Last=266.0, Close=269.5, Volume=5519316, Turnover=154425000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 11, 0, 0), Open=266.8, High=267.0, Low=247.95, Last=247.95, Close=247.95, Volume=2427606, Turnover=61821900000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 12, 0, 0), Open=244.0, High=251.5, Low=236.6, Last=244.0, Close=244.75, Volume=2805072, Turnover=68361600000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 13, 0, 0), Open=246.0, High=255.6, Low=243.1, Last=243.15, Close=244.5, Volume=3226776, Turnover=80683500000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 14, 0, 0), Open=245.0, High=245.0, Low=238.1, Last=239.05, Close=239.2, Volume=1506543, Turnover=36240600000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 17, 0, 0), Open=244.4, High=251.0, Low=232.3, Last=236.1, Close=235.9, Volume=4385887, Turnover=105359000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 18, 0, 0), Open=236.9, High=241.0, Low=233.75, Last=236.5, Close=236.45, Volume=2706614, Turnover=64307400000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 19, 0, 0), Open=240.9, High=247.5, Low=240.0, Last=243.0, Close=243.95, Volume=2511949, Turnover=61450800000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 20, 0, 0), Open=243.0, High=244.8, Low=236.25, Last=237.9, Close=237.7, Volume=1158464, Turnover=27873800000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 21, 0, 0), Open=238.75, High=239.75, Low=235.5, Last=237.0, Close=237.45, Volume=1178627, Turnover=27999600000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 24, 0, 0), Open=236.65, High=240.35, Low=227.1, Last=228.1, Close=228.3, Volume=1855636, Turnover=43583600000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 25, 0, 0), Open=226.0, High=227.9, Low=222.6, Last=225.5, Close=224.85, Volume=2226513, Turnover=50123300000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 27, 0, 0), Open=229.0, High=235.5, Low=228.0, Last=230.8, Close=230.15, Volume=2000745, Turnover=46439000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 28, 0, 0), Open=232.7, High=248.6, Low=232.7, Last=248.6, Close=248.5, Volume=4978231, Turnover=122105000000000.0)
#
# Row(Date=datetime.datetime(2000, 1, 31, 0, 0), Open=246.0, High=256.75, Low=242.5, Last=242.95, Close=244.7, Volume=4829071, Turnover=121300000000000.0)

# %% [markdown]
# We Use describe() to learn about the DataFrame.

# %%
df.describe().show()
# Out:
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+--------------------+
# |summary|             Open|             High|              Low|             Last|            Close|              Volume|            Turnover|
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+--------------------+
# |  count|             5306|             5306|             5306|             5306|             5306|                5306|                5306|
# |   mean|967.1821145872661|982.1015831134682|950.8985865058337|965.7270260082915|965.8955427817613|1.0039301876931775E7|4.136854066509612E14|
# | stddev|858.9254750256306| 870.739800614141|845.7612311747486|857.5102297628137|857.7665370712187|1.7831893107142422E7|4.578376582709872...|
# |    min|           142.85|           147.95|           140.05|           140.55|           141.45|                3633|           7.6806E10|
# |    max|           3505.0|           3515.0|          3451.35|           3499.0|          3489.95|           262677081|          8.54908E15|
# +-------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+--------------------+

# %% [markdown]
# We will get the Summary Statistics of the Data.

# %%
from pyspark.sql.functions import format_number

summary = df.describe()
summary.select(summary['summary'],
                  format_number(summary['Open'].cast('float'), 2).alias('Open'),
                  format_number(summary['High'].cast('float'), 2).alias('High'),
                  format_number(summary['Low'].cast('float'), 2).alias('Low'),
                  format_number(summary['Close'].cast('float'), 2).alias('Close'),
                  format_number(summary['Volume'].cast('double'),0).alias('Volume'),
                  format_number(summary['Turnover'].cast('double'),0).alias('Turnover')
                 ).show()
# Out:
# +-------+--------+--------+--------+--------+-----------+--------------------+
# |summary|    Open|    High|     Low|   Close|     Volume|            Turnover|
# +-------+--------+--------+--------+--------+-----------+--------------------+
# |  count|5,306.00|5,306.00|5,306.00|5,306.00|      5,306|               5,306|
# |   mean|  967.18|  982.10|  950.90|  965.90| 10,039,302| 413,685,406,650,961|
# | stddev|  858.93|  870.74|  845.76|  857.77| 17,831,893| 457,837,658,270,987|
# |    min|  142.85|  147.95|  140.05|  141.45|      3,633|      76,806,000,000|
# |    max|3,505.00|3,515.00|3,451.35|3,489.95|262,677,081|8,549,080,000,000...|
# +-------+--------+--------+--------+--------+-----------+--------------------+

# %% [markdown]
# Create a new dataframe with a column called HV Ratio that is the ratio of the High Price versus volume of stock traded for a day.

# %%
df_hv = df.withColumn('HV Ratio', df['High']/df['Volume']).select(['HV Ratio'])
df_hv.show()
# Out:
# +--------------------+
# |            HV Ratio|
# +--------------------+
# |1.026660733819085...|
# |5.827737852336244...|
# |7.708081808752211E-5|
# | 4.02474859963528E-5|
# |3.554743881274856E-5|
# |5.251556533454508E-5|
# |1.099848987026725...|
# |8.965901766514371E-5|
# |7.921219198357742E-5|
# |1.626239675867200...|
# |5.722901661625117E-5|
# |8.904114144092952E-5|
# |9.852907045485398E-5|
# |2.113142920280647...|
# |2.034146511152383...|
# |1.295243248137026...|
# |1.023573632851009...|
# |1.177061544574646E-4|
# | 4.99374175284353E-5|
# |5.316757612385487...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# The day that had peak High in the price

# %%
df.orderBy(df['High'].desc()).select(['Date']).head(1)[0]['Date']
# Out:
# Out[19]: datetime.datetime(2010, 11, 8, 0, 0)

# %% [markdown]
# Mean of the Close column.

# %%
from pyspark.sql.functions import mean

df.select(mean('Close')).show()
# Out:
# +-----------------+
# |       avg(Close)|
# +-----------------+
# |965.8955427817613|
# +-----------------+

# %% [markdown]
# Maximum and Minimum of the Volume column

# %%
from pyspark.sql.functions import min, max

df.select(max('Volume'),min('Volume')).show()
# Out:
# +-----------+-----------+
# |max(Volume)|min(Volume)|
# +-----------+-----------+
# |  262677081|       3633|
# +-----------+-----------+

# %% [markdown]
# No of days where the Close was greater than 300 Rupees?

# %%
df.filter(df['Close'] > 300).count()
# Out:
# Out[22]: 3289

# %% [markdown]
# percentage of the time when the High was greater than 250 Rupees.

# %%
df.filter('High > 250').count() * 100/df.count()
# Out:
# Out[23]: 79.11797964568413

# %% [markdown]
# This shows the Pearson Correlation between High and Low

# %%
df.corr('High', 'Low')
# Out:
# Out[24]: 0.9995691609533329

# %% [markdown]
# This shows the Pearson Correlation value.

# %%
from pyspark.sql.functions import corr

df.select(corr(df['High'], df['Low'])).show()
# Out:
# +------------------+
# |   corr(High, Low)|
# +------------------+
# |0.9995691609533329|
# +------------------+

# %% [markdown]
# Shows Max High per Year

# %%
from pyspark.sql.functions import (dayofmonth, hour,
                                   dayofyear, month,
                                   year, weekofyear,
                                  format_number, date_format)

year_df = df.withColumn('Year', year(df['Date']))

year_df.groupBy('Year').max()['Year', 'max(High)'].show()
# Out:
# +----+---------+
# |Year|max(High)|
# +----+---------+
# |2003|   552.65|
# |2007|   2476.0|
# |2018|   332.75|
# |2015|    336.0|
# |2006|   1617.4|
# |2013|   2551.7|
# |2014|   2979.0|
# |2019|    373.8|
# |2004|    689.9|
# |2020|   339.85|
# |2012|   2475.0|
# |2009|   2500.0|
# |2016|    288.8|
# |2001|    275.9|
# |2005|    960.0|
# |2000|   289.85|
# |2010|   3515.0|
# |2011|  2960.05|
# |2008|   2574.0|
# |2017|    351.3|
# +----+---------+
# only showing top 20 rows

# %% [markdown]
# Shows average close for each calendar Month.

# %%
#Create a new column Month from existing Date column
month_df = df.withColumn('Month', month(df['Date']))

#Group by month and take average of all other columns
month_df = month_df.groupBy('Month').mean()

#Sort by month
month_df = month_df.orderBy('Month')

#Display only month and avg(Close), the desired columns
month_df['Month', 'avg(Close)'].show()
# Out:
# +-----+------------------+
# |Month|        avg(Close)|
# +-----+------------------+
# |    1| 932.7772435897435|
# |    2| 917.2679310344824|
# |    3| 892.1004405286336|
# |    4|  918.907345971564|
# |    5| 968.5095768374166|
# |    6| 965.8547884187085|
# |    7| 977.6757575757572|
# |    8| 964.9864253393667|
# |    9|1021.5986078886306|
# |   10| 1039.602680652681|
# |   11| 1034.456839622642|
# |   12| 963.8319727891167|
# +-----+------------------+
